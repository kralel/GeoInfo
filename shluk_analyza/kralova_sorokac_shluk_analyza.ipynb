# %% [markdown]
# # Shluková analýza

# %%
import numpy as np
from math import *
from matplotlib import pyplot as plt
import sklearn.cluster

# %%
ax = np.asarray(np.random.uniform(5, 25, 20))
ay = np.asarray(np.random.uniform(5, 10, 20))
bx = np.asarray(np.random.uniform(-10, 2, 20))
by = np.asarray(np.random.uniform(-10, 5, 20))
cx = np.asarray(np.random.uniform(2, 10, 20))
cy = np.asarray(np.random.uniform(-2, 15, 20))
dx = np.asarray(np.random.uniform(-5, 10, 20))
dy = np.asarray(np.random.uniform(0, 15, 20))
ex = np.asarray(np.random.uniform(10 , 25, 20))
ey = np.asarray(np.random.uniform(-2, 5, 20))

x = np.concatenate((ax, bx, cx, dx, ex))
y = np.concatenate((ay, by, cy, dy, ey))

# %%
plt.scatter(ax, ay, c="red", s=10)
plt.scatter(bx, by, c="blue", s=10)
plt.scatter(cx, cy, c="yellow", s=10)
plt.scatter(dx, dy, c="green", s=10)
plt.scatter(ex, ey, c="orange", s=10)
plt.show()

# %%
data = list(zip(x, y))
print(data)
kmeans = sklearn.cluster.KMeans(n_clusters = 5)
kmeans.fit(data)


plt.scatter(x, y, c=kmeans.labels_, s=10)
plt.show
# Out:
# [(np.float64(5.660686608268608), np.float64(8.882620935466502)), (np.float64(23.87169808909969), np.float64(7.986783108410935)), (np.float64(24.757849205051436), np.float64(8.946448985586395)), (np.float64(17.170173853247043), np.float64(8.532235019301638)), (np.float64(12.68925189232039), np.float64(7.153696935507087)), (np.float64(14.211761285060762), np.float64(7.013516525290893)), (np.float64(18.010504735916584), np.float64(9.533406037237508)), (np.float64(7.858486301110692), np.float64(9.821368665717513)), (np.float64(20.857972480063022), np.float64(7.591119048328514)), (np.float64(23.942299124274648), np.float64(6.275224750238736)), (np.float64(8.327013398522991), np.float64(6.1165957959551065)), (np.float64(24.383463453235223), np.float64(7.823810715398295)), (np.float64(16.632022722505727), np.float64(5.943908342050594)), (np.float64(10.5951741502576), np.float64(5.695073892179674)), (np.float64(16.226112043431005), np.float64(6.337229329076667)), (np.float64(8.510513365055521), np.float64(6.65424785571402)), (np.float64(12.593014449738023), np.float64(6.883076433184606)), (np.float64(7.040633623588106), np.float64(7.459091549402665)), (np.float64(18.19283286864195), np.float64(7.525167253293532)), (np.float64(22.52665310871693), np.float64(9.22745344694804)), (np.float64(1.2872430712097653), np.float64(-5.860146031976061)), (np.float64(0.017400671336522677